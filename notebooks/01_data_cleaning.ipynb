# %%
import os; os.getcwd()
# Out:
# 'C:\\Users\\SenriLtd\\Downloads\\Stock-out-Prediction'

# %%
import pandas as pd
train = pd.read_csv('data/raw/train.csv')
train.head()
# Out:
# C:\Users\SenriLtd\AppData\Local\Temp\ipykernel_16884\2001865849.py:2: DtypeWarning: Columns (0: StateHoliday) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('data/raw/train.csv')
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
